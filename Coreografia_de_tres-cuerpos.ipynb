# %% [markdown]
# # coreografia de tres cuerpos

# %%
# !pip install -Uq pymcel celluloid
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 76.0 MB/s eta 0:00:00:00:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 73.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 52.6 MB/s eta 0:00:00

# %%
import pymcel as pc
import numpy as np
import matplotlib.pyplot as plt
from celluloid import Camera
# Out:
# Bienvenido a PyMCel v0.9.18 ¡al infinito y más allá!

# %%
G = 1.0          # constante gravitacional (normalizada)
m1 = 1.0          # masa de cada cuerpo
m2 = 1.0          # masa de cada cuerpo
m3 = 1.0          # masa de cada cuerpo
dt = 0.001       # paso de tiempo
T = 10           # tiempo total de simulación
steps = int(T/dt)

# %%
#posiciones iniciales 
r1 = np.array([0.97000436, -0.24308753])  
r2 = np.array([-0.97000436, 0.24308753]) 
r3 = np.array([0.0, 0.0])                   
#velocidades iniciales
v1 = np.array([0.466203685, 0.43236573])   
v2 = np.array([0.466203685, 0.43236573])   
v3 = np.array([-0.93240737, -0.86473146])
